# %% [markdown]
# <a href="https://colab.research.google.com/github/chinmayhandi/CIE-01/blob/main/CIE_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv('/content/auto-mpg(1).csv')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    int64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.030151  2970.424623
# std      7.815984    1.701004    104.269838   38.387644   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   92.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
x=df[['weight']]
y=df[['mpg']]
print("X:",x)
# Out:
# X:      weight
# 0      3504
# 1      3693
# 2      3436
# 3      3433
# 4      3449
# ..      ...
# 393    2790
# 394    2130
# 395    2295
# 396    2625
# 397    2720
#
# [398 rows x 1 columns]

# %%
sns.scatterplot(x='weight',y='mpg',data=df)
plt.show()

# %%
print("Y:",y)
# Out:
# Y:       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [398 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      weight
# 3      3433
# 18     2130
# 376    2025
# 248    1800
# 177    2694
# ..      ...
# 71     2330
# 106    4499
# 270    2515
# 348    2050
# 102    1950
#
# [318 rows x 1 columns]

# %%
x_test
# Out:
#      weight
# 198    1795
# 396    2625
# 33     2634
# 208    3940
# 93     4237
# ..      ...
# 249    3365
# 225    3520
# 367    2605
# 175    1937
# 285    3840
#
# [80 rows x 1 columns]

# %%
y_train
# Out:
#       mpg
# 3    16.0
# 18   27.0
# 376  37.0
# 248  36.1
# 177  23.0
# ..    ...
# 71   19.0
# 106  12.0
# 270  21.1
# 348  37.7
# 102  26.0
#
# [318 rows x 1 columns]

# %%
y_test
# Out:
#       mpg
# 198  33.0
# 396  28.0
# 33   19.0
# 208  13.0
# 93   14.0
# ..    ...
# 249  19.9
# 225  17.5
# 367  28.0
# 175  29.0
# 285  17.0
#
# [80 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [[32.77165335]
#  [26.29330219]
#  [26.22305501]
#  [16.0294085 ]
#  [13.71125152]
#  [30.39105443]
#  [24.42004403]
#  [ 9.82424083]
#  [15.09277942]
#  [24.34199161]
#  [16.73188031]
#  [31.44476215]
#  [31.52281457]
#  [16.40406013]
#  [26.94113731]
#  [ 8.10708751]
#  [26.68356431]
#  [22.27360238]
#  [13.84394064]
#  [31.40573593]
#  [27.18309982]
#  [24.66981178]
#  [24.6542013 ]
#  [30.58618549]
#  [19.43249417]
#  [30.15689716]
#  [29.10318944]
#  [25.39569932]
#  [20.16618695]
#  [ 8.48954439]
#  [25.00543721]
#  [31.32768351]
#  [16.3416182 ]
#  [29.00172129]
#  [31.02327906]
#  [13.39123659]
#  [27.48750427]
#  [20.04910831]
#  [11.67408327]
#  [29.46223059]
#  [25.70790902]
#  [32.46724889]
#  [23.88928755]
#  [10.76086991]
#  [27.22212603]
#  [29.92273989]
#  [29.25148904]
#  [25.93426105]
#  [28.24461278]
#  [29.43100962]
#  [27.98703978]
#  [31.36670972]
#  [28.90805838]
#  [12.26728169]
#  [25.51277796]
#  [11.93946151]
#  [16.0294085 ]
#  [25.62205135]
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
rmse=np.sqrt(mse)

print("Mean Squared Error:",mse)
print("Root Mean Squared Error:",rmse)
print("Mean Absolute Error:",mae)
print("R2 Score:",r2)
# Out:
# Mean Squared Error: 14.894861064636194
# Root Mean Squared Error: 3.8593860994510765
# Mean Absolute Error: 3.1177861992064573
# R2 Score: 0.722971057303075

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred,color='blue')
plt.title('Linear Regression')
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.show()
