# %% [markdown]
# <a href="https://colab.research.google.com/github/chinmayhandi/CIE-01/blob/main/CIE_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv('/content/drive/MyDrive/Datasets/auto_mpg_sample (1).csv')
df.head()
# Out:
#    mpg  weight  price
# 0   18    3504   2000
# 1   22    3200   2500
# 2   25    2800   2700
# 3   30    2600   3000
# 4   35    2200   3500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     20 non-null     int64
#  1   weight  20 non-null     int64
#  2   price   20 non-null     int64
# dtypes: int64(3)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#              mpg       weight        price
# count  20.000000    20.000000    20.000000
# mean   27.100000  2912.700000  2827.500000
# std     7.319045   630.333671   619.523374
# min    15.000000  2000.000000  1800.000000
# 25%    21.500000  2437.500000  2425.000000
# 50%    27.500000  2850.000000  2850.000000
# 75%    32.250000  3276.000000  3162.500000
# max    40.000000  4200.000000  4000.000000

# %%
x=df[['mpg']]
y=df[['price']]
print("X:",x)
# Out:
# X:     mpg
# 0    18
# 1    22
# 2    25
# 3    30
# 4    35
# 5    15
# 6    28
# 7    32
# 8    20
# 9    40
# 10   27
# 11   23
# 12   31
# 13   36
# 14   19
# 15   17
# 16   24
# 17   29
# 18   33
# 19   38

# %%
print("Y:",y)
# Out:
# Y:     price
# 0    2000
# 1    2500
# 2    2700
# 3    3000
# 4    3500
# 5    1800
# 6    2900
# 7    3100
# 8    2200
# 9    4000
# 10   2800
# 11   2600
# 12   3200
# 13   3600
# 14   2100
# 15   1900
# 16   2750
# 17   3050
# 18   3150
# 19   3700

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#     mpg
# 8    20
# 5    15
# 11   23
# 3    30
# 18   33
# 16   24
# 13   36
# 2    25
# 9    40
# 19   38
# 4    35
# 12   31
# 7    32
# 10   27
# 14   19
# 6    28

# %%
x_test
# Out:
#     mpg
# 0    18
# 17   29
# 15   17
# 1    22

# %%
y_train
# Out:
#     price
# 8    2200
# 5    1800
# 11   2600
# 3    3000
# 18   3150
# 16   2750
# 13   3600
# 2    2700
# 9    4000
# 19   3700
# 4    3500
# 12   3200
# 7    3100
# 10   2800
# 14   2100
# 6    2900

# %%
y_test
# Out:
#     price
# 0    2000
# 17   3050
# 15   1900
# 1    2500

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [[2077.36398964]
#  [2985.00647668]
#  [1994.85103627]
#  [2407.41580311]]

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
rmse=np.sqrt(mse)

print("Mean Squared Error:",mse)
print("Root Mean Squared Error:",rmse)
print("Mean Absolute Error:",mae)
print("R2 Score:",r2)
# Out:
# Mean Squared Error: 6944.474390252111
# Root Mean Squared Error: 83.33351300798563
# Mean Absolute Error: 82.44818652849756
# R2 Score: 0.9668075906664574
